# %% [markdown]
# <font size="+2"><p style="text-align: center;"><b> Auswertung Versuch 223 PAP 2.1. </p></font>

# %% [markdown]
# ## 3.1 importieren und graphische Darstellung der Messdaten:
# Mithilfe von Jupyter werden wir nun die Bewegung des Teilchens graphisch auswerten.
# Dafür werden die Positionswerte eingelesen und in einem xy - Diagramm geplottet (Diagramm 1):

# %%
from IPython.display import Image
Image("figures/brown1.png")

# %% [markdown]
# ## 3.2 Berechnung des mittleren Verschiebungsquadrat und dessen Fehler:
# Im nächsten Teil der Auswertung werden wir nun die Koordinatenänderungen betrachten um die Boltzmann Konstante zu bestimmen.<center><br>$\Delta x_i=x_{i+1}-x_i$ und $\Delta y_i=y_{i+1}-y_i$</center>
# Daraus berechnet sich das Verschiebungsquadrat :
#
# <center><br>${\langle r \rangle}^2 = \Delta x^2+\Delta y^2$  </center>
#
# Gemittelt erhalten wir folgenden Wert für das Verschiebungsquadrat:
#
# <center><br>${\langle r \rangle}^2 = (1,98 \pm 0,12)\cdot10^{-12}m^2  $</center>
#
# Die gemittelte Zeit zwischen zwei Messungen beträgt:
#
# <center><br>$t=(1,0010 \pm 0,0005)s$  </center>

# %% [markdown]
# wir wollen die Bolzmannkonstante anhand von Gleichung (12) bestimmen.
# Hierzu benötigen wir noch den Teilchenradius, welchen wir anhand des Durchmessers erhalten haben (siehe Messprotokoll).
# Auch benötigen wir Die Temperatur und die Viskosität von Wasser, welche aus dem Skript stammt:
#
# $a= (377,5 \pm 15)nm$
#
# $T = (22,8 \pm 1)°C$
#
# $\eta=(9,4 \pm 0,25)\cdot 10^{-4} Pa \cdot s$

# %% [markdown]
# Mithilfe von (12) erhalten wir: <center><br> $k = \frac{6 \pi \eta a}{4 T t}\cdot {\langle r \rangle}^2 = (1,118\pm 0,009)\cdot 10^{-23} \frac{J}{K}$  </center>
#
# mit
#
# <center><br> $\Delta k=k \cdot \sqrt{\left(\frac{\Delta \eta}{\eta}\right)^2+\left(\frac{\Delta a}{a}\right)^2+\left(\frac{\Delta T}{T}\right)^2+\left(\frac{\Delta t}{t}\right)^2+\left(\frac{\Delta {\langle r \rangle}^2}{{\langle r \rangle}^2}\right)^2}$  </center>

# %% [markdown]
# Der Literaturwert der Boltzmannkonstante lautet nach <a href="https://de.wikipedia.org/wiki/Boltzmann-Konstante">https://de.wikipedia.org/wiki/Boltzmann-Konstante</a>
#
#
# <center><br>$k_{lit}= 1,381 \cdot 10^{-23} \frac{J}{K}$ </center>

# %% [markdown]
# Vergleichen wir unseren Wert hiermit, können wir erkennen, dass der errechnete Wert in einer 3 $\sigma$ - Umgebung liegt.

# %% [markdown]
# Mit unserem errechneten Wert können wir nun die Diffusionskonstante D bestimmen. Wir verwenden hierfür Gleichung (11).
#
# <center><br>$D=\frac{k T }{6 \pi \eta a}$  </center>
#
# Nach Einsetzten der Werte erhalten wir nun:
#
# <center><br>$D=(4,95\pm 0,46)\cdot 10^{-13} \frac{m^2}{s}$  </center>
#
# Der Fehler wurde berechnet mit:
#
# <center><br> $\Delta D=D \cdot \sqrt{\left(\frac{\Delta k}{k}\right)^2+\left(\frac{\Delta T}{T}\right)^2+\left(\frac{\Delta \eta}{\eta}\right)^2+\left(\frac{\Delta a}{a}\right)^2}$  </center>

# %% [markdown]
# ## 3.3 Kontrollverteilung :
#
# im nächsten Teil des Versuches wollen wir zeigen, dass es sich bei unseren Werten um eine Gaußverteilung handelt, wie Gleichung (5) vorhersagt.
# Dafür lesen wir die Verschiebung $\Delta x$ und $\Delta y$ in ein Histogramm ein, wobei beide Verschiebungsrichtungen in eines eingetragen werden.
# Außerdem erhalten wir durch Phython den Mittelwert der Verschiebung $\mu$ und die Standartabweichung $\sigma$.

# %%
from IPython.display import Image
Image("figures/gauss.png")

# %% [markdown]
# ## 3.4 Kumulative Verteilung der Verschiebungsquadrate:
# Nach Gleichung (6) ist das mittlere Verschiebungsquadrat ${\langle r \rangle}^2=4Dt$
# proportional zur Zeit.
# Wir tragen die kumulative Verschiebung ${\langle r \rangle}^2$ gegen die Zeit auf und erhalten eine Gerade, siehe Diagramm 3.
# Mithilfe der Steigung können wir nun den Diffusiondkoeffizient berechnen.
# Wobei die Steigung $m=\frac{{\langle r \rangle}^2}{t}$ ist:
#
# <center><br>$D=\frac{{\langle r \rangle}^2}{4t}  = \frac{m}{4}=(4,893\pm 0,019) \cdot 10^{-13} \frac{\mu m^2}{s}$  </center>
# mit Fehler aus dem lineren Regression im Pythonskript.
#
# Wir können nun also nach (11) die Boltzmannkonstante berechnen:
#
# <center><br>$k'=\frac{6 \pi \eta a D}{T} = (1,126\pm 0,054) \cdot 10^{-23} \frac{J}{K}$  </center>
#
# Den Fehler haben wir erhalten mit:
#
# <center><br>$\Delta k'=k' \cdot \sqrt{\left(\frac{\Delta \eta}{\eta}\right)^2+\left(\frac{\Delta a}{a}\right)^2+\left(\frac{\Delta T}{T}\right)^2+\left(\frac{\Delta D}{D}\right)^2}$  </center>

# %% [markdown]
# Vergleichen wir den neuen Wert für die Boltzmannkonstane mit dem Literaturwert, können wir erkennen, dass der errechnete Wert nur in einer 5 $\sigma$ - Umgebung liegt, das heißt es liegt eine signifikante Abweichung vor.

# %%
from IPython.display import Image
Image("figures/kumulativ.png")

# %% [markdown]
# Vergleichen wir nun die Werte der Boltzmann- und Diffusionskonstanten aus dem 1. und 2. Teil der Auswertung,
# so können wir erkennen, dass die Werte für die Boltzmannkonstante und die Diffunsionskonstante jeweils beide nur eine Abweichung von 0,07 $\sigma$ haben.
# Dies bedeutet es gibt keine signifikante Abweichung.
